# %%
import pandas as pd
import anndata as ad

# %%
gdsc = pd.read_csv("/cluster/work/boeva/eheiss/datasets/GDSC/rnaseq_merged_20260323/rnaseq_merged_20260323.csv")

# %%
gdsc_matrix = gdsc.pivot_table(
    index="model_name",        # rows = cell lines
    columns="ensembl_gene_id", # columns = genes
    values="rsem_expected_count"
)

# %%
gdsc_matrix
# Out:
# ensembl_gene_id  ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# model_name
# 1273-99                   1189.0              0.0           3849.3
# 143B                      3563.0              0.0           5754.7
# 170-MG-BA                 2636.0              4.0           3940.0
# 22RV1                      504.0              0.0           3354.0
# 23132-87                   580.0              0.0           4433.0
# ...                          ...              ...              ...
# ZR-75-1                    427.0              0.0           4217.1
# ZR-75-30                  2817.0              0.0           5485.0
# huH-1                     1946.0              0.0           5480.0
# no-10                     5243.0              0.0           9064.0
# no-11                    12967.0              3.0          10458.0
#
# ensembl_gene_id  ENSG00000000457  ENSG00000000460  ENSG00000000938  \
# model_name
# 1273-99                   504.79          1249.20              4.0
# ...

# %%
adata = ad.AnnData(
    X=gdsc_matrix.values,                      # expression matrix
    obs=pd.DataFrame(index=gdsc_matrix.index), # cell lines
    var=pd.DataFrame(index=gdsc_matrix.columns) # genes
)

# %%
adata.write("/cluster/work/boeva/eheiss/datasets/GDSC/gdsc.h5ad")
