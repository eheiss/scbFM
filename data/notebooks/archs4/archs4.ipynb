# %% [markdown]
# ## Part I - Import and reorganization to homogene h5ad structure

# %%
# see archs4.py (cluster job due to memory requirements)

# %% [markdown]
# ## Part II - Statistics

# %%
# see archs4_2.py (cluster job due to memory requirements)

# %% [markdown]
# ## Part III - Filter to gene list

# %%
# see archs4_2.py (cluster job due to memory requirements)
