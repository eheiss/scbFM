# %%
import pandas as pd
import scanpy as sc

# %%
gtex = pd.read_parquet("/Users/enricoheiss/Thesis/eheiss/datasets/GTEx/GTEx_Analysis_2025-08-22_v11_RNASeQCv2.4.3_gene_reads.parquet")

# %%
gtex
# Out:
#                    Description  GTEX-1117F-0005-SM-HL9SH  \
# Name
# ENSG00000290825.2     DDX11L16                         0
# ENSG00000223972.6      DDX11L1                         0
# ENSG00000310526.1       WASH7P                        90
# ENSG00000243485.6  MIR1302-2HG                         0
# ENSG00000237613.3      FAM138A                         0
# ...                        ...                       ...
# ENSG00000198695.2       MT-ND6                      1533
# ENSG00000210194.1        MT-TE                         0
# ENSG00000198727.2       MT-CYB                     14981
# ENSG00000210195.2        MT-TT                         0
# ENSG00000210196.2        MT-TP                         0
#
#                    GTEX-1117F-0011-R10b-SM-GI4VE  \
# Name
# ENSG00000290825.2                              0
# ENSG00000223972.6                              0
# ENSG00000310526.1                            137
# ENSG00000243485.6                              0
# ...
